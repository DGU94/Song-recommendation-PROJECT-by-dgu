# %%
import numpy as np
import pandas as pd
import pickle
from sklearn import datasets # sklearn comes with some toy datasets to practise
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from matplotlib import pyplot
from sklearn.metrics import silhouette_score

# %%
Song_DB = pd.read_csv('Song_DataBase.csv')

# %%
Song_DB.drop(['id'], axis=1, inplace=True)

# %%
# We will not use the 'target' key as we don't want to classify the wines in types.
# we just want to cluster them.
X = Song_DB

print()
X.head()
# Out:
#    Unnamed: 0  danceability  energy  loudness  speechiness  acousticness  \
# 0           0         0.669   0.698    -7.971       0.0713       0.02430
# 1           1         0.544   0.897    -6.056       0.0471       0.24100
# 2           2         0.514   0.942    -8.433       0.0502       0.28200
# 3           3         0.527   0.835    -5.298       0.0433       0.01660
# 4           4         0.767   0.881    -3.988       0.0301       0.00133
#
#    instrumentalness  liveness  valence    tempo  duration_ms
# 0          0.000000    0.0782    0.600   83.987       261707
# 1          0.000000    0.1300    0.647  157.170       215133
# 2          0.000066    0.1700    0.912  159.847       175267
# 3          0.000000    0.2490    0.654  125.983       176658
# 4          0.000139    0.0551    0.961  130.018       209800

# %%
#Song_DB.describe()

# %%
scaler = StandardScaler()
scaler.fit(X)
X_scaled = scaler.transform(X)
X_scaled_df = pd.DataFrame(X_scaled, columns = X.columns)
display(X.head())
print()
display(X_scaled_df.head())
# Out:
#    Unnamed: 0  danceability  energy  loudness  speechiness  acousticness  \
# 0           0         0.669   0.698    -7.971       0.0713       0.02430
# 1           1         0.544   0.897    -6.056       0.0471       0.24100
# 2           2         0.514   0.942    -8.433       0.0502       0.28200
# 3           3         0.527   0.835    -5.298       0.0433       0.01660
# 4           4         0.767   0.881    -3.988       0.0301       0.00133
#
#    instrumentalness  liveness  valence    tempo  duration_ms
# 0          0.000000    0.0782    0.600   83.987       261707
# 1          0.000000    0.1300    0.647  157.170       215133
# 2          0.000066    0.1700    0.912  159.847       175267
# 3          0.000000    0.2490    0.654  125.983       176658
# 4          0.000139    0.0551    0.961  130.018       209800
#    Unnamed: 0  danceability    energy  loudness  speechiness  acousticness  \
# 0   -1.737667      0.476280 -0.451023 -0.537226     0.046482     -0.500911
# 1   -1.737250     -0.383530  0.857515  0.133972    -0.358223      0.769494
# 2   -1.736833     -0.589884  1.153416 -0.699155    -0.306381      1.009857
# 3   -1.736416     -0.500464  0.449830  0.399647    -0.421772     -0.546052
# 4   -1.736000      1.150370  0.752306  0.858795    -0.642520     -0.635572
#
#    instrumentalness  liveness   valence     tempo  duration_ms
# 0         -0.301758 -0.748979 -0.030153 -1.490447     0.546256
# 1         -0.301758 -0.424485  0.182371  1.251789    -0.277262
# 2         -0.301342 -0.173911  1.380647  1.352099    -0.982170
# 3         -0.301758  0.320974  0.214024  0.083183    -0.957574
# 4         -0.300882 -0.893686  1.602214  0.234378    -0.371560

# %% [markdown]
# ## Clustering the wines with K-Means

# %%
kmeans = KMeans(n_clusters=3, random_state=1234)
kmeans.fit(X_scaled_df)
# Out:
# KMeans(n_clusters=3, random_state=1234)

# %%
# assign a cluster to each example
labels = kmeans.predict(X_scaled_df)
# retrieve unique clusters
clusters = np.unique(labels)
# create scatter plot for samples from each cluster
for cluster in clusters:
    # get row indexes for samples with this cluster
    row_ix = np.where(labels == cluster)
    # create scatter of these samples
    pyplot.scatter(X.to_numpy()[row_ix, 1], X.to_numpy()[row_ix, 3])
    # show the plot
pyplot.show()

# %%
clusters = kmeans.predict(X_scaled_df)
#clusters
pd.Series(clusters).value_counts().sort_index()
# Out:
# 0    2897
# 1    3775
# 2    1588
# dtype: int64

# %%
#X_df = pd.DataFrame(X)
X["cluster"] = clusters
X
# Out:
#       Unnamed: 0  danceability  energy  loudness  speechiness  acousticness  \
# 0              0         0.669   0.698    -7.971       0.0713      0.024300
# 1              1         0.544   0.897    -6.056       0.0471      0.241000
# 2              2         0.514   0.942    -8.433       0.0502      0.282000
# 3              3         0.527   0.835    -5.298       0.0433      0.016600
# 4              4         0.767   0.881    -3.988       0.0301      0.001330
# ...          ...           ...     ...       ...          ...           ...
# 8255        8314         0.433   0.959    -4.040       0.0431      0.000917
# 8256        8315         0.389   0.873    -4.768       0.0475      0.005320
# 8257        8316         0.543   0.944    -7.495       0.0543      0.402000
# 8258        8317         0.573   0.897    -3.549       0.0553      0.004730
# 8259        8318         0.504   0.911    -2.970       0.0738      0.005120
#
#       instrumentalness  liveness  valence    tempo  duration_ms  cluster
# 0             0.000000    0.0782    0.600   83.987       261707        1
# 1             0.000000    0.1300    0.647  157.170       215133        0
# 2             0.000066    0.1700    0.912  159.847       175267        1
# 3             0.000000    0.2490    0.654  125.983       176658        1
# 4             0.000139    0.0551    0.961  130.018       209800        1
# ...                ...       ...      ...      ...          ...      ...
# 8255          0.000000    0.0280    0.365  172.984       269373        0
# 8256          0.005500    0.2730    0.303  106.767       312293        0
# 8257          0.000564    0.0373    0.735  101.174       279440        1
# 8258          0.000000    0.2780    0.463  126.034       210653        0
# 8259          0.012300    0.3550    0.671  106.244       179760        0
#
# [8260 rows x 12 columns]

# %%
X[X['cluster'] == 2].sample()
# Out:
#       Unnamed: 0  danceability  energy  loudness  speechiness  acousticness  \
# 3275        3316         0.453   0.607     -13.4       0.0345         0.337
#
#       instrumentalness  liveness  valence   tempo  duration_ms  cluster
# 3275            0.0237    0.0998    0.724  91.468       221891        2

# %%
kmeans.inertia_
# Out:
# 72917.34221202647

# %%
kmeans2 = KMeans(n_clusters=3,
                init="k-means++",
                n_init=50,  # try with 1, 4, 8, 20, 30, 100...
                max_iter=1,
                tol=0,
                algorithm="elkan",
                random_state=1234)
kmeans2.fit(X_scaled_df)
print(kmeans2.inertia_)
# Out:
# 74077.87215795352

# %% [markdown]
# ## Chosing K

# %%
K = range(2, 21)
inertia = []

for k in K:
    print("Training a K-Means model with {} clusters! ".format(k))
    print()
    kmeans = KMeans(n_clusters=k,
                    random_state=1234)
    kmeans.fit(X_scaled_df)
    inertia.append(kmeans.inertia_)

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(16,8))
plt.plot(K, inertia, 'bx-')
plt.xlabel('k')
plt.ylabel('inertia')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Elbow Method showing the optimal k')
# Out:
# Training a K-Means model with 2 clusters!
#
# Training a K-Means model with 3 clusters!
#
# Training a K-Means model with 4 clusters!
#
# Training a K-Means model with 5 clusters!
#
# Training a K-Means model with 6 clusters!
#
# Training a K-Means model with 7 clusters!
#
# Training a K-Means model with 8 clusters!
#
# Training a K-Means model with 9 clusters!
#
# Training a K-Means model with 10 clusters!
#
# Training a K-Means model with 11 clusters!
#
# Training a K-Means model with 12 clusters!
#
# Training a K-Means model with 13 clusters!
#
# Training a K-Means model with 14 clusters!
#
# Training a K-Means model with 15 clusters!
#
# Training a K-Means model with 16 clusters!
#
# Training a K-Means model with 17 clusters!
#
# Training a K-Means model with 18 clusters!
#
# Training a K-Means model with 19 clusters!
#
# Training a K-Means model with 20 clusters!
# Text(0.5, 1.0, 'Elbow Method showing the optimal k')

# %% [markdown]
# ## Silouhette

# %%
K = range(2, 20)
silhouette = []

for k in K:
    kmeans = KMeans(n_clusters=k,
                    random_state=1234)
    kmeans.fit(X_scaled_df)
    
    filename = "Model/kmeans_" + str(k) + ".pickle"
    with open(filename, "wb") as f:
        pickle.dump(kmeans,f)
    
    silhouette.append(silhouette_score(X_scaled_df, kmeans.predict(X_scaled_df)))


plt.figure(figsize=(16,8))
plt.plot(K, silhouette, 'bx-')
plt.xlabel('k')
plt.ylabel('silhouette score')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Silhouette Method showing the optimal k')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/d0/kyjzvmwn3fdgc5m0t8snt0nm0000gn/T/ipykernel_44182/1173907512.py in <module>
#       8
#       9     filename = "Model/kmeans_" + str(k) + ".pickle"
# ---> 10     with open(filename, "wb") as f:
#      11         pickle.dump(kmeans,f)
#      12
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Model/kmeans_2.pickle'
